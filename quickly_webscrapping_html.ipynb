# %%
import pandas as pd

# %%
import pandas as pd
data = pd.read_html("https://en.wikipedia.org/wiki/Super_Bowl_LIV")
print(len(data)) # show how mayn tables in the page
# Out:
# 25

# %%
df = data[4]
df
# Out:
#                                       Scoring summary  \
# 0   Quarter Time Drive Team Scoring information Sc...
# 1                                             Quarter
# 2                                             Quarter
# 3                                                   1
# 4                                                   1
# 5                                                   2
# 6                                                   2
# 7                                                   3
# 8                                                   3
# 9                                                   4
# 10                                                  4
# 11                                                  4
# 12  "TOP" = time of possession. For other American...
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                Time
# ...

# %%
# Delete rows 0, 1, 12
df = df.drop([0, 1, 12], axis=0)
df
# Out:
#    Scoring summary Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2          Quarter       Time      Plays      Yards        TOP       Team
# 3                1       7:57         10         62       5:58         SF
# 4                1       0:31         15         75       7:26         KC
# 5                2       9:32          9         43       4:36         KC
# 6                2       5:05          7         80       4:27         SF
# 7                3       9:29          9         60       5:31         SF
# 8                3       2:35          6         55       2:48         SF
# 9                4       6:13         10         83       2:40         KC
# 10               4       2:44          7         65       2:26         KC
# 11               4       1:12          2         42       0:13         KC
#
#                                            Unnamed: 6 Unnamed: 7 Unnamed: 8
# 2                                 Scoring information         SF         KC
# ...

# %%
# Annoiyng columns
df.iloc[0]
# Out:
# Scoring summary                Quarter
# Unnamed: 1                        Time
# Unnamed: 2                       Plays
# Unnamed: 3                       Yards
# Unnamed: 4                         TOP
# Unnamed: 5                        Team
# Unnamed: 6         Scoring information
# Unnamed: 7                          SF
# Unnamed: 8                          KC
# Name: 2, dtype: object

# %%
# Putting the dataframe in a List to eliminate the annoiyng columns
df.columns = list(df.iloc[0])
df
# Out:
#     Quarter  Time  Plays  Yards   TOP  Team  \
# 2   Quarter  Time  Plays  Yards   TOP  Team
# 3         1  7:57     10     62  5:58    SF
# 4         1  0:31     15     75  7:26    KC
# 5         2  9:32      9     43  4:36    KC
# 6         2  5:05      7     80  4:27    SF
# 7         3  9:29      9     60  5:31    SF
# 8         3  2:35      6     55  2:48    SF
# 9         4  6:13     10     83  2:40    KC
# 10        4  2:44      7     65  2:26    KC
# 11        4  1:12      2     42  0:13    KC
#
#                                   Scoring information  SF  KC
# 2                                 Scoring information  SF  KC
# 3                  38-yard field goal by Robbie Gould   3   0
# 4   Patrick Mahomes 1-yard touchdown run, Harrison...   3   7
# 5                        31-yard field goal by Butker   3  10
# 6   Kyle Juszczyk 15-yard touchdown reception from...  10  10
# 7                         42-yard field goal by Gould  13  10
# ...

# %%
# Delete the row 2
df = df.drop(2, axis=0)
df
# Out:
#    Quarter  Time Plays Yards   TOP Team  \
# 3        1  7:57    10    62  5:58   SF
# 4        1  0:31    15    75  7:26   KC
# 5        2  9:32     9    43  4:36   KC
# 6        2  5:05     7    80  4:27   SF
# 7        3  9:29     9    60  5:31   SF
# 8        3  2:35     6    55  2:48   SF
# 9        4  6:13    10    83  2:40   KC
# 10       4  2:44     7    65  2:26   KC
# 11       4  1:12     2    42  0:13   KC
#
#                                   Scoring information  SF  KC
# 3                  38-yard field goal by Robbie Gould   3   0
# 4   Patrick Mahomes 1-yard touchdown run, Harrison...   3   7
# 5                        31-yard field goal by Butker   3  10
# 6   Kyle Juszczyk 15-yard touchdown reception from...  10  10
# 7                         42-yard field goal by Gould  13  10
# 8   Raheem Mostert 1-yard touchdown run, Gould kic...  20  10
# 9   Travis Kelce 1-yard touchdown reception from M...  20  17
# ...

# %%
# Reset the index, import to set 'drop=True' cause not will create a new column
df = df.reset_index(drop=True)
df
# Out:
#   Quarter  Time Plays Yards   TOP Team  \
# 0       1  7:57    10    62  5:58   SF
# 1       1  0:31    15    75  7:26   KC
# 2       2  9:32     9    43  4:36   KC
# 3       2  5:05     7    80  4:27   SF
# 4       3  9:29     9    60  5:31   SF
# 5       3  2:35     6    55  2:48   SF
# 6       4  6:13    10    83  2:40   KC
# 7       4  2:44     7    65  2:26   KC
# 8       4  1:12     2    42  0:13   KC
#
#                                  Scoring information  SF  KC
# 0                 38-yard field goal by Robbie Gould   3   0
# 1  Patrick Mahomes 1-yard touchdown run, Harrison...   3   7
# 2                       31-yard field goal by Butker   3  10
# 3  Kyle Juszczyk 15-yard touchdown reception from...  10  10
# 4                        42-yard field goal by Gould  13  10
# 5  Raheem Mostert 1-yard touchdown run, Gould kic...  20  10
# 6  Travis Kelce 1-yard touchdown reception from M...  20  17
# 7  Damien Williams 5-yard touchdown reception fro...  20  24
# ...
